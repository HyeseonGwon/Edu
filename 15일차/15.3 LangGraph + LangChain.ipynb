# %% [markdown]
# # LangGraph + LangChain
# * 15.1에서 만든 **Node · Graph**와 15.2의 **`add_messages` · Conditional Edge**에 LangChain LLM을 연결합니다.

# %% [markdown]
# ---
# * `day15` Conda 환경을 사용합니다.
# * LangChain OpenAI 연동 패키지를 추가로 설치합니다.

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (1.3.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-openai) (1.4.8)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-openai) (2.44.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.9.2)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.7.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.16.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: tqdm>4 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.68.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.4.2)
# Requirement already satisfied: regex in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.5.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\Admin\miniconda3\envs\day4\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)

# %%
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = __import__('os').getenv('OPENAI_API_KEY')

WORKDIR = Path.cwd()
print('WORKDIR :', WORKDIR)
# Out:
# WORKDIR : c:\Users\Admin\Desktop\실습\15일차

# %% [markdown]
# ---
# ## Node 안에서 LangChain LLM 호출
#
# Node 안에서 **`ChatOpenAI.invoke()`** 로 실제 LLM 응답을 받습니다.
#
# | Message 타입 | 역할 |
# |----------------|------|
# | `HumanMessage` | 사용자 메시지 |
# | `AIMessage` | 모델 응답 메시지 |
# | `SystemMessage` | 시스템 프롬프트 (역할·규칙 지정) |

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.7, api_key=OPENAI_API_KEY)

# 그래프 밖에서 먼저 단독 호출해 봅니다
demo_reply = llm.invoke([
    SystemMessage(content='한 문장으로만 답하세요.'),
    HumanMessage(content='LangGraph가 뭐야?'),
])
demo_reply.content
# Out:
# 'LangGraph는 언어 모델과 그래프 기반의 데이터 구조를 결합하여 자연어 처리와 관련된 작업을 수행하는 시스템이나 프레임워크입니다.'

# %% [markdown]
# * Node 내부에서 LangChain 기반 LLM을 실행해 보겠습니다

# %%
from pydantic import BaseModel

class ChatState(BaseModel):
    question: str = ''
    answer: str = ''

# %%
def chat_node(state: ChatState) -> dict:
    """LangChain LLM을 Node 안에서 1회 호출합니다."""
    response = llm.invoke([
        SystemMessage(content='친절한 한국어 어시스턴트입니다. 2문장 이내로 답하세요.'),
        HumanMessage(content=state.question),
    ])
    return {'answer': response.content}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(ChatState)
workflow.add_node('chat', chat_node)
workflow.add_edge(START, 'chat')
workflow.add_edge('chat', END)

single_app = workflow.compile()

# %%
result = single_app.invoke(ChatState(question='LangGraph의 Node는 무엇을 하나요?'))
print('질문:', result['question'])
print('답변:', result['answer'])
# Out:
# 질문: LangGraph의 Node는 무엇을 하나요?
# 답변: LangGraph의 Node는 언어 처리와 관련된 다양한 정보나 데이터를 저장하고 연결하는 역할을 합니다. 이를 통해 노드 간의 관계를 모델링하고, 언어적 패턴을 분석할 수 있습니다.

# %%
for chunk in single_app.stream(ChatState(question='LangGraph에서 Edge는 무엇인가요?')):
    print(chunk)
# Out:
# {'chat': {'answer': 'LangGraph에서 Edge는 노드 간의 관계를 나타내는 연결선으로, 노드들 사이의 상호작용이나 정보를 전달하는 역할을 합니다. 이를 통해 데이터의 흐름이나 구조를 시각적으로 표현할 수 있습니다.'}}

# %% [markdown]
# ---
# ## `chat_history`에 LangChain 메시지 저장
#
# LangChain의 `HumanMessage` / `AIMessage`를 그대로 history에 쌓고,
# 다음 턴에 **전체 history를 LLM에 넘겨** 맥락을 유지합니다.

# %%
from typing import Annotated

from pydantic import Field
from langgraph.graph.message import add_messages
from langchain_core.messages import BaseMessage


class ChatState(BaseModel):
    # 15.2와 동일: add_messages → Node는 새 메시지 리스트만 반환
    chat_history: Annotated[list[BaseMessage], add_messages] = Field(default_factory=list)  # Reducer 추가
    question: str = ''  # 이번 턴에 추가할 사용자 질문

# %%
def multi_chat_node(state: ChatState) -> dict:
    # 이번 턴 사용자 메시지를 history에 추가
    user_msg = HumanMessage(content=state.question) # -> HumanMessage: 사용자(인간)의 메시지를 저장하는 메시지 클래스
    messages_for_llm = state.chat_history + [user_msg]

    # 지금까지의 대화 전체를 LLM에 전달
    response = llm.invoke([
        SystemMessage(content='친절한 한국어 어시스턴트입니다. 이전 대화를 기억하세요.'),
        *messages_for_llm,
    ])

    # add_messages 덕분에 [user_msg, response]만 반환해도 기존 history에 이어 붙음
    return {'chat_history': [user_msg, response]}


multi_workflow = StateGraph(ChatState)
multi_workflow.add_node('chat', multi_chat_node)
multi_workflow.add_edge(START, 'chat')
multi_workflow.add_edge('chat', END)

multi_app = multi_workflow.compile()

# %% [markdown]
# ## 이름 기억 테스트

# %%
state = multi_app.invoke(ChatState(question='내 이름은 민수야. 기억해줘.'))

print('--- 1턴 ---')
for msg in state['chat_history']:
    role = '사용자' if msg.type == 'human' else 'AI'
    print(f'[{role}] {msg.content}')
# Out:
# --- 1턴 ---
# [사용자] 내 이름은 민수야. 기억해줘.
# [AI] 안녕하세요, 민수님! 반갑습니다. 어떻게 도와드릴까요?

# %%
# 이전 state를 이어서 새 질문만 넣습니다
state = multi_app.invoke(ChatState(
    chat_history=state['chat_history'],
    question='내 이름이 뭐였지?',
))

print('--- 2턴 이후 전체 history ---')
for msg in state['chat_history']:
    role = '사용자' if msg.type == 'human' else 'AI'
    print(f'[{role}] {msg.content}')
# Out:
# --- 2턴 이후 전체 history ---
# [사용자] 내 이름은 민수야. 기억해줘.
# [AI] 안녕하세요, 민수님! 반갑습니다. 어떻게 도와드릴까요?
# [사용자] 내 이름이 뭐였지?
# [AI] 민수님이시죠! 어떻게 도와드릴까요?

# %%
#다르게 쓰는 방법

state['question'] = "내 이름이 뭐지?"
state = multi_app.invoke(state)

print('--- 2턴 이후 전체 history ---')
for msg in state['chat_history']:
    role = '사용자' if msg.type == 'human' else 'AI'
    print(f'[{role}] {msg.content}')
# Out:
# --- 2턴 이후 전체 history ---
# [사용자] 내 이름은 민수야. 기억해줘.
# [AI] 안녕하세요, 민수님! 반갑습니다. 어떻게 도와드릴까요?
# [사용자] 내 이름이 뭐였지?
# [AI] 민수님이시죠! 어떻게 도와드릴까요?
# [사용자] 내 이름이 뭐지?
# [AI] 민수님이십니다! 다른 질문이 있으신가요?

# %% [markdown]
# ### `add_messages`가 필요한 이유
#
# add_message 속성 추가 없이 Node가 **새 메시지만** 반환하면
# 기존 history가 **통째로 덮어써져** 이전 대화가 사라집니다.

# %%
class BrokenChatState(BaseModel):
    chat_history: list[BaseMessage] = Field(default_factory=list) # -> Annotated[, add_messages] 없음
    question: str = ''


def broken_chat_node(state: BrokenChatState) -> dict:
    user_msg = HumanMessage(content=state.question)
    response = llm.invoke([HumanMessage(content=state.question)])
    return {'chat_history': [user_msg, response]}  # 기존 history 무시 → 덮어쓰기


broken_app = StateGraph(BrokenChatState)
broken_app.add_node('chat', broken_chat_node)
broken_app.add_edge(START, 'chat')
broken_app.add_edge('chat', END)
broken_app = broken_app.compile()

s1 = broken_app.invoke(BrokenChatState(question='내 이름은 영희야.'))
s2 = broken_app.invoke(BrokenChatState(
    chat_history=s1['chat_history'],
    question='내 이름이 뭐였지?',
))

print('history 메시지 수:', len(s2['chat_history']))
print('마지막 AI 답:', s2['chat_history'][-1].content)
# Out:
# history 메시지 수: 2
# 마지막 AI 답: 죄송하지만, 당신의 이름을 알 수 없습니다. 당신의 이름을 알려주시면 그에 맞춰 대화할 수 있습니다!

# %% [markdown]
# ### `input()` 기반으로 채팅하기
# * LangGraph로 완전한 멀티턴 대화를 구현하려면, 대화 지속/종료를 선택하는 분기가 필요합니다
# * `add_conditional_edges`와 적절한 `router`를 활용해 `input()` 기반으로 채팅을 구현해 보세요

# %%
# 외부에서 입력을 받아 invoke하는 방식으로 해보자.
# 채팅을 끝내는 라우터도 필요.

from typing import Annotated

from pydantic import Field
from langgraph.graph.message import add_messages
from langchain_core.messages import BaseMessage

class ChatState(BaseModel):
    chat_history: Annotated[list[BaseMessage], add_messages] = Field(default_factory=list)
    question: str = ''           # 이번 턴 사용자 입력
    should_end: bool = False     # 종료 여부 (router가 참고)

def input_node(state: ChatState) -> dict:
    """사용자 입력을 받고, 종료 키워드면 should_end=True"""
    user_input = input("\n[User]: ").strip()

    if user_input.lower() in ('q', 'quit', 'exit', '종료'):
        print("채팅을 종료합니다.")
        return {'should_end': True, 'question': ''}

    return {'question': user_input, 'should_end': False}

def multi_chat_node(state: ChatState) -> dict:
    """이번 턴 질문을 history에 추가하고 LLM 호출"""
    user_msg = HumanMessage(content=state.question)
    messages_for_llm = state.chat_history + [user_msg]

    response = llm.invoke([
        SystemMessage(content='You are a kind AI Assistant. You MUST answer in Korean Language.'),
        *messages_for_llm,
    ])
    print(f"[User]: {user_msg.content}")
    print(f"[AI]: {response.content}")
    return {'chat_history': [user_msg, response]}

multi_workflow = StateGraph(ChatState)
multi_workflow.add_node('input', input_node)
multi_workflow.add_node('chat', multi_chat_node)

multi_workflow.add_edge(START, 'input')
multi_workflow.add_edge('chat', 'input')     # chat 후 다시 input으로 (다음 턴)
# END / conditional edge는 다음 셀에서

# %%
def end_chat_router(state: ChatState) -> str:
    """input 직후: 종료면 END, 아니면 chat으로"""
    if state.should_end:
        return END
    return 'chat'

multi_workflow.add_conditional_edges('input', end_chat_router)

multi_app = multi_workflow.compile()
# router 구현 후, conditonal edge를 추가해야 합니다.

# %%
# 그래프가 input → chat → input → ... 를 반복하다가
# 사용자가 q/quit/exit/종료 입력 시 END

final_state = multi_app.invoke(ChatState())

print("\n=== 대화 종료 ===")
print(f"총 메시지 수: {len(final_state['chat_history'])}")
# Out:
# [User]: 안녕? 난 권혜선이야.
# [AI]: 안녕하세요, 권혜선님! 만나서 반갑습니다. 어떻게 도와드릴까요?
# [User]: 내 이름이 뭐게?
# [AI]: 권혜선님이라고 하셨죠? 맞나요?
# [User]: 그래 안녕~
# [AI]: 안녕하세요~ 권혜선님! 오늘 기분이 어떠신가요?
# 채팅을 종료합니다.
#
# === 대화 종료 ===
# 총 메시지 수: 6

# %%
# Cell 1: START → chat → END (기존 multi_chat_node 패턴)
# Cell 2: router 없이 compile

current_state = {
    "chat_history": [],
    "question": "",
    "should_end": False,
}

while True:
    user_input = input("\n[User]: ").strip()
    if user_input.lower() in ('q', 'quit', 'exit', '종료'):
        print("채팅을 종료합니다.")
        break

    current_state = multi_app.invoke({
        **current_state,
        "question": user_input,
    })

    # chat_node에서 print 안 했다면 여기서 출력
    # print(f"[AI]: {current_state['chat_history'][-1].content}")
# Out:
# 채팅을 종료합니다.
# 채팅을 종료합니다.

# %% [markdown]
# ---
# ## 순환 그래프 — AI끼리 대화 시켜보기
#
# 15.2의 **A ↔ B ↔ judge** 순환 구조에 LangChain LLM을 넣습니다.
#
# | Node | 역할 |
# |------|------|
# | `optimist` | 낙관론자 — 주제에 찬성·긍정 |
# | `skeptic` | 회의론자 — 반박·비판 |
#
# **중단 조건** (`debate_route`):
# * `turn_count >= max_turns` → `END`
# * 마지막 메시지에 `'합의'` 포함 → `END`
# * 그 외 → `optimist`로 돌아가 순환

# %%
from typing import Literal


class DebateState(BaseModel):
    chat_history: Annotated[list[BaseMessage], add_messages] = Field(default_factory=list)
    topic: str
    turn_count: int = 0          # optimist가 말할 때마다 +1
    max_turns: int = 3           # optimist 3번 = 총 6메시지 입력 시 종료
    last_speaker: Literal['optimist', 'skeptic'] = 'skeptic'


optimist_llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.8, api_key=OPENAI_API_KEY)
skeptic_llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.8, api_key=OPENAI_API_KEY)

# %%
def optimist_node(state: DebateState) -> dict:
    prompts = [
        SystemMessage(content=(
            '당신은 낙관적인 토론자입니다. 주제에 찬성하는 입장을 말하고,'
            '상대 토론자의 주장이 있다면 반박하세요'
        )),
    ]
    if not state.chat_history:
        prompts.append(HumanMessage(content=f'토론 주제: {state.topic}')) # 첫 대화이면 토론 주제를 주고
    else:
        prompts.extend(state.chat_history) # 이전 대화가 있으면 이어서 대화

    # Q. 굳이 Prompt 작성 -> extend 방식으로 구현하는 이유는?
    # A. node 별로 System Prompt가 다르기 때문에, 각각의 llm에게 system prompt는 다르게 주고
    # 대화 history는 똑같이 줘야 하기 때문

    response = optimist_llm.invoke(prompts) # llm으로부터 응답을 받고
    response.name = 'optimist' # 응답(AIMessage 형식)의 name 필드를 채워준 다음 return
    return {
        'chat_history': [response],
        'last_speaker': 'optimist',
        'turn_count': state.turn_count + 1,
    } 


def skeptic_node(state: DebateState) -> dict:
    prompts = [
        SystemMessage(content=(
            '당신은 비판적인 토론자입니다. 상대 주장을 반박하세요. 2문장 이내. '
            '더 이상 반박이 어려워 패배를 인정한다면 "합의"라고 말하십시오'
        )),
        *state.chat_history,
    ]
    response = skeptic_llm.invoke(prompts)
    response.name = 'skeptic'
    return {
        'chat_history': [response],
        'last_speaker': 'skeptic',
    }

# %% [markdown]
# ### `route` 함수와 Conditional Edge 구현
# * `debate_route`는 **다음에 갈 Node 이름** 또는 `END`를 반환합니다.
# * `add_conditional_edges('skeptic', debate_route)`

# %%
def debate_route(state: DebateState):
    if state.turn_count >= state.max_turns:
        return END
    last_text = state.chat_history[-1].content if state.chat_history else ''
    if '합의' in last_text:
        return END
    return 'optimist'


debate_workflow = StateGraph(DebateState)
debate_workflow.add_node('optimist', optimist_node)
debate_workflow.add_node('skeptic', skeptic_node)

debate_workflow.add_edge(START, 'optimist')
debate_workflow.add_edge('optimist', 'skeptic')
debate_workflow.add_conditional_edges('skeptic', debate_route)

debate_app = debate_workflow.compile()

# %%
init_debate = DebateState(topic='AI 발전은 인간의 행복에 긍정적인 영향을 줄 것이다.')

for chunk in debate_app.stream(init_debate):
    print(chunk)

# %% [markdown]
# ## 사회자 추가하기
#
# 토론 그래프에 **`moderator` Node**를 추가해 보세요.
#
# * 매 라운드 끝에 양쪽 주장을 한 줄로 요약
# * `debate_route`에서 `moderator`를 거친 뒤 `optimist`로 보내기
# * 사회자가 '종료'를 언급해야 토론이 종료되도록 종료 조건 수정
